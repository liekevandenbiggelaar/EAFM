# %%
from Code.visualizations import plot_poincare
import random
import numpy as np

# %%
rr_manual = np.array([random.randint(66, 120) for i in range(1000)])

# %%
sd1, sd2 = plot_poincare(rr_manual)
print("SD1: %.3f ms" % sd1)
print("SD2: %.3f ms" % sd2)
# Out:
# SD1: 16.045 ms
# SD2: 15.692 ms
